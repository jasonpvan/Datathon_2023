# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
from zipfile import ZipFile

# %%
file_name = "datathon.zip"

with ZipFile(file_name, 'r') as zip:
  zip.extractall()

# %%
with open("Fotos_Fuera.txt") as f:
    mylist = f.read().splitlines()
i = 0
for s in mylist:
  if (i%5==0):
    print("New Outfit:")
  i = i+1
  img = mpimg.imread(s)
  plt.imshow(img)
  plt.show()
# Out:
# New Outfit:
# New Outfit:
# New Outfit:
# New Outfit:
# New Outfit:
